# %%
import pandas as pd
import numpy as np
from load_data import *
import yfinance as yf

# %%
start = "2022-01-10"
end = "2023-04-28"
data_nvs = get_data(['NVS'], start, end)
data_abbv = get_data(['ABBV'], start, end)
data_azn = get_data(['AZN'], start, end)
data_bmy = get_data(['BMY'], start, end)
data_jnj = get_data(['JNJ'], start, end)
data_lly = get_data(['LLY'], start, end)
data_mrk = get_data(['MRK'], start, end)
data_nvo = get_data(['NVO'], start, end)
data_pfe = get_data(['PFE'], start, end)
data_rog = get_data(['ROG'], start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_nvs.head(5)
# Out:
#            ticker      close  close_lag    return   volume       high  \
# Date
# 2022-01-18    NVS  82.362442  83.291489 -1.115416  2318300  89.839996
# 2022-01-19    NVS  81.727760  82.362442 -0.770596  2044200  89.320000
# 2022-01-20    NVS  81.120667  81.727760 -0.742824  2066000  89.150002
# 2022-01-21    NVS  80.053650  81.120667 -1.315345  2781600  88.029999
# 2022-01-24    NVS  78.305954  80.053650 -2.183156  3887800  85.129997
#
#                   low  rolling_var_5    target
# Date
# 2022-01-18  89.010002      -0.938959 -1.828237
# 2022-01-19  88.650002      -1.046452 -2.641561
# 2022-01-20  88.139999      -1.046452 -3.462090
# 2022-01-21  86.910004      -1.275359 -4.518732
# 2022-01-24  83.290001      -2.009594 -6.316816

# %%
dfs = [data_abbv, data_azn, data_bmy, data_jnj, data_lly, data_mrk, data_nvo, data_pfe, data_rog]

# %%
covs = []
for d in dfs:
    covs.append(d['target'])

covs
# Out:
# [Date
#  2022-01-18   -3.655271
#  2022-01-19   -5.699553
#  2022-01-20   -7.654667
#  2022-01-21   -7.634319
#  2022-01-24   -7.712493
#                  ...
#  2023-04-21   -4.204795
#  2023-04-24   -4.336565
#  2023-04-25   -3.066301
#  2023-04-26   -3.580081
#  2023-04-27   -9.424741
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18   -0.371873
#  2022-01-19   -1.335989
#  2022-01-20   -2.306917
#  2022-01-21   -3.425557
#  2022-01-24   -6.284836
#                  ...
#  2023-04-21   -4.557931
#  2023-04-24   -3.901360
#  2023-04-25   -3.244789
#  2023-04-26   -4.417002
#  2023-04-27   -5.525381
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18   -3.067622
#  2022-01-19   -4.525571
#  2022-01-20   -3.921134
#  2022-01-21   -4.320768
#  2022-01-24   -4.994158
#                  ...
#  2023-04-21   -2.418511
#  2023-04-24   -2.592321
#  2023-04-25   -2.621110
#  2023-04-26   -4.717771
#  2023-04-27   -6.840508
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18    -5.209877
#  2022-01-19    -4.950229
#  2022-01-20    -4.657772
#  2022-01-21    -4.363549
#  2022-01-24    -4.413721
#                  ...
#  2023-04-21    -9.420443
#  2023-04-24   -11.576554
#  2023-04-25    -9.597240
#  2023-04-26    -8.663146
#  2023-04-27    -7.729052
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18    -8.751056
#  2022-01-19   -12.042402
#  2022-01-20   -12.165432
#  2022-01-21   -11.665372
#  2022-01-24   -10.256005
#                  ...
#  2023-04-21    -3.377309
#  2023-04-24    -3.227412
#  2023-04-25    -2.938351
#  2023-04-26    -4.166728
#  2023-04-27    -5.395106
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18   -4.111988
#  2022-01-19   -3.783863
#  2022-01-20   -3.540497
#  2022-01-21   -3.613813
#  2022-01-24   -4.146126
#                  ...
#  2023-04-21   -2.128847
#  2023-04-24   -2.392976
#  2023-04-25   -2.618794
#  2023-04-26   -4.200277
#  2023-04-27   -5.689957
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18    -8.017222
#  2022-01-19   -10.296922
#  2022-01-20   -12.721371
#  2022-01-21   -14.581994
#  2022-01-24   -13.164387
#                  ...
#  2023-04-21    -7.813079
#  2023-04-24   -10.145321
#  2023-04-25   -12.146153
#  2023-04-26   -11.712162
#  2023-04-27   -11.278171
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18    -4.695499
#  2022-01-19    -7.368884
#  2022-01-20    -9.215126
#  2022-01-21    -9.615277
#  2022-01-24   -10.150961
#                  ...
#  2023-04-21    -6.576231
#  2023-04-24    -7.054904
#  2023-04-25    -6.986451
#  2023-04-26    -7.324162
#  2023-04-27    -7.620930
#  Name: target, Length: 321, dtype: float64,
#  Date
#  2022-01-18   -0.726409
#  2022-01-19   -0.789438
#  2022-01-20   -0.735030
#  2022-01-21   -0.701682
#  2022-01-24   -0.671816
#                  ...
#  2023-04-21   -3.116739
#  2023-04-24   -2.893903
#  2023-04-25   -3.054954
#  2023-04-26   -4.060696
#  2023-04-27   -5.066437
#  Name: target, Length: 321, dtype: float64]

# %%
gc = granger_causality(data_nvs['target'], covs)
gc
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 gc = granger_causality(data_nvs['target'], covs)
#       2 gc
#
# File c:\Users\HP\Desktop\Barcelona\Term3\Thesis\load_data.py:72, in granger_causality(target, covariates)
#      59 """
#      60 Computes Granger causality between a target series and multiple control series
#      61 Goal: Identify good predictor series for a Ticker
#    (...)
#      68    dict: a dictionary with the results of the Granger causality tests
#      69 """
#      71 # Combine the target and control series into one datafram
# ---> 72 data = pd.concat([target, covariates], axis=1)
#      73 data.columns = ['target'] + [f'control_{i+1}' for i in range(len(covariates))]
#      75 # Compute Granger causality for each control series
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\concat.py:458, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     453     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     454         msg = (
#     455             f"cannot concatenate object of type '{type(obj)}'; "
#     456             "only Series and DataFrame objs are valid"
#     457         )
# --> 458         raise TypeError(msg)
#     460     ndims.add(obj.ndim)
#     462 # get the sample
#     463 # want the highest ndim that we have, and must be non-empty
#     464 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'list'>'; only Series and DataFrame objs are valid
